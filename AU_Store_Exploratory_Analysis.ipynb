# %%
import pandas as pd
import warnings

# %%
#Loading the file
df = pd.read_csv('AU_Store_Closure-Opening_Dataset_For_Analysis.csv')

# %%
#Checking the first 5 rows
df.head()
# Out:
#            ds_id  brand_name               store_brand_key  \
# 0      shiels_au      Shiels  RO_BRAND_198989c993093b3ffff
# 1  tyre_right_au  Tyre Right   RO_BRAND_82989be5daf077ffff
# 2  tyre_right_au  Tyre Right   RO_BRAND_82989be1a0a353ffff
# 3  tyre_right_au  Tyre Right   RO_BRAND_82989a7006da77ffff
# 4      adidas_au      Adidas   RO_BRAND_571899c23110afffff
#
#                                    store_name type_of_event timestamp  \
# 0                             Shiels Mandurah    OPEN_STORE    8_2023
# 1  Tyreright Red Cliffs Mobile Tyre Servicing    OPEN_STORE    8_2023
# 2                     Tyreright Coffs Harbour    OPEN_STORE    8_2023
# 3   Tyreright Geraldton Mobile Tyre Servicing    OPEN_STORE    8_2023
# 4                  Adidas Outlet Store Cairns    OPEN_STORE    8_2023
#
#   snapshot_date         category                 sub_category  \
# 0    2023-08-31  Retail Shopping  Jewellery & Watch Retailers
# 1    2023-08-31       Automotive                        Tyres
# 2    2023-08-31       Automotive                        Tyres
# 3    2023-08-31       Automotive                        Tyres
# 4    2023-08-31  Retail Shopping     Sporting Goods Retailers
#
#   broader_top_category         suburb state postal_code           sa1
# 0          Specialties       MANDURAH    WA        6210  5.020110e+10
# 1           Non Retail     RED CLIFFS   VIC           0  2.150214e+10
# 2           Non Retail  COFFS HARBOUR   NSW        2450  1.040211e+10
# 3           Non Retail      WEBBERTON    WA        6530  5.110413e+10
# 4          Specialties      WESTCOURT   QLD        4870  3.060212e+10

# %%
#Checking the last 5 rows
df.tail()
# Out:
#                         ds_id           brand_name  \
# 19304           bottlemart_au           Bottlemart
# 19305  little_red_dumpling_au  Little Red Dumpling
# 19306           bottlemart_au           Bottlemart
# 19307             my_house_au             My House
# 19308        coles_express_au                Coles
#
#                     store_brand_key                             store_name  \
# 19304  RO_BRAND_192489be6234a37ffff  Bottlemart at Silvan Licenced Grocers
# 19305  RO_BRAND_191989beab2a6b7ffff         Little Red Dumpling Broadbeach
# 19306  RO_BRAND_192489a726c74afffff                          Railway Hotel
# 19307  RO_BRAND_185689be73b053bffff                         MyHouse Albury
# 19308  RO_BRAND_229689be0b8d527ffff                 Coles Express Bathurst
#
#       type_of_event timestamp snapshot_date category sub_category  \
# 19304   CLOSE_STORE    5_2023    2023-04-30      NaN          NaN
# 19305   CLOSE_STORE    5_2023    2023-04-30      NaN          NaN
# 19306   CLOSE_STORE   12_2022    2022-11-30      NaN          NaN
# 19307   CLOSE_STORE    3_2023    2023-02-28      NaN          NaN
# 19308    OPEN_STORE    2_2023    2023-02-28      NaN          NaN
#
#       broader_top_category suburb state postal_code  sa1
# 19304                  NaN    NaN   NaN         NaN  NaN
# 19305                  NaN    NaN   NaN         NaN  NaN
# 19306                  NaN    NaN   NaN         NaN  NaN
# 19307                  NaN    NaN   NaN         NaN  NaN
# 19308                  NaN    NaN   NaN         NaN  NaN

# %%
#Shape of the Dataframe
df.shape
# Out:
# (19309, 14)

# %%
#Columns and their Names
df.columns
# Out:
# Index(['ds_id', 'brand_name', 'store_brand_key', 'store_name', 'type_of_event',
#        'timestamp', 'snapshot_date', 'category', 'sub_category',
#        'broader_top_category', 'suburb', 'state', 'postal_code', 'sa1'],
#       dtype='object')

# %%
#Information about the Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19309 entries, 0 to 19308
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ds_id                 19309 non-null  object
#  1   brand_name            19309 non-null  object
#  2   store_brand_key       19309 non-null  object
#  3   store_name            19303 non-null  object
#  4   type_of_event         19309 non-null  object
#  5   timestamp             19309 non-null  object
#  6   snapshot_date         19309 non-null  object
#  7   category              9891 non-null   object
#  8   sub_category          9891 non-null   object
#  9   broader_top_category  9785 non-null   object
#  10  suburb                9824 non-null   object
#  11  state                 9824 non-null   object
#  12  postal_code           9779 non-null   object
#  13  sa1                   9789 non-null   float64
# dtypes: float64(1), object(13)
# memory usage: 2.1+ MB

# %%
#Description of the data
df.describe(include = 'object')
# Out:
#              ds_id    brand_name              store_brand_key store_name  \
# count        19309         19309                        19309      19303
# unique         617           613                        16895      11964
# top     westpac_au  Westpac Bank  RO_BRAND_74789be630b603ffff     Subway
# freq          1648          1648                            8         66
#
#        type_of_event timestamp snapshot_date         category sub_category  \
# count          19309     19309         19309             9891         9891
# unique             2         9            10               20          100
# top       OPEN_STORE    5_2023    2023-05-31  Retail Shopping        Banks
# freq            9806      4223          3217             2751         1440
#
#        broader_top_category  suburb state postal_code
# count                  9785    9824  9824        9779
# unique                    7    2345     8        1488
# top             Specialties  YATALA   NSW           0
# freq                   3994      81  3118         132

# %%
#Finding out the Null Values
df.isnull().sum()
# Out:
# ds_id                      0
# brand_name                 0
# store_brand_key            0
# store_name                 6
# type_of_event              0
# timestamp                  0
# snapshot_date              0
# category                9418
# sub_category            9418
# broader_top_category    9524
# suburb                  9485
# state                   9485
# postal_code             9530
# sa1                     9520
# dtype: int64

# %%
#Removing the Duplicates
df.drop_duplicates(inplace = True)

# %%
#Exporting the Clean Dataframe
df.to_csv('stores_clean_data.csv', index=False)
